# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import pickle

# %%
df = pd.read_csv('../Data/SaYoPillow.csv')

# %%
col_mapping = {"sr" : "snoring_rate",
                "rr" : "respiration_rate",
                "t" : "body_temperature",
                "lm" : "limb_movement",
                "bo" : "blood_oxygen",
                "rem" : "eye_movement",
                "sr.1" : "sleeping_rate",
                "hr" : "heart_rate",
                "sl" : "stress_level"
                }

df.rename(columns=col_mapping, inplace=True)
df.head()
# Out:
#    snoring_rate  respiration_rate  body_temperature  limb_movement  \
# 0         93.80            25.680            91.840         16.600
# 1         91.64            25.104            91.552         15.880
# 2         60.00            20.000            96.000         10.000
# 3         85.76            23.536            90.768         13.920
# 4         48.12            17.248            97.872          6.496
#
#    blood_oxygen  eye_movement  sleeping_rate  heart_rate  stress_level
# 0        89.840         99.60          1.840       74.20             3
# 1        89.552         98.88          1.552       72.76             3
# 2        95.000         85.00          7.000       60.00             1
# 3        88.768         96.92          0.768       68.84             3
# 4        96.248         72.48          8.248       53.12             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   snoring_rate      630 non-null    float64
#  1   respiration_rate  630 non-null    float64
#  2   body_temperature  630 non-null    float64
#  3   limb_movement     630 non-null    float64
#  4   blood_oxygen      630 non-null    float64
#  5   eye_movement      630 non-null    float64
#  6   sleeping_rate     630 non-null    float64
#  7   heart_rate        630 non-null    float64
#  8   stress_level      630 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 44.4 KB

# %%
df['stress_level'].value_counts()
# Out:
# stress_level
# 3    126
# 1    126
# 0    126
# 2    126
# 4    126
# Name: count, dtype: int64

# %%
x = df.drop('stress_level', axis=1)
y = df['stress_level']
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=70, random_state=111)

# %%
log_model = LogisticRegression()
log_model.fit(x_train, y_train)
# log_model.score(x,y)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_model.predict(x_test)
acc1 = accuracy_score(y_test, y_pred)
print("Logistic Regression - Accuracy: ", acc1)
# Out:
# Logistic Regression - Accuracy:  1.0

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# rf.score(x,y)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = rf.predict(x_test)
acc2 = accuracy_score(y_test, y_pred2)
print("Random Forest - Accuracy: ", acc2)
# Out:
# Random Forest - Accuracy:  0.9785714285714285

# %%
xgb = XGBClassifier()
xgb.fit(x_train,y_train)
# xgb.score(x,y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred3 = rf.predict(x_test)
acc3 = accuracy_score(y_test, y_pred3)
print("Xgboost - Accuracy: ", acc3)
# Out:
# Xgboost - Accuracy:  0.9785714285714285

# %%
with open('../Models/xgb_classifier.bin', 'wb') as f_out:
    pickle.dump(xgb,f_out)

with open('../Models/logistic_regression.bin', 'wb') as f_out1:
    pickle.dump(log_model,f_out1)

# %%
x_test
# Out:
#      snoring_rate  respiration_rate  body_temperature  limb_movement  \
# 158        96.320            26.320            85.400         17.160
# 353        85.160            23.376            90.688         13.720
# 150        88.520            24.272            91.136         14.840
# 194        98.304            28.304            87.880         18.152
# 12         48.600            17.440            98.160          6.880
# ..            ...               ...               ...            ...
# 363        71.840            21.184            93.184         11.184
# 391        57.920            19.584            95.584          9.584
# 466        91.280            25.008            91.504         15.760
# 610        93.680            25.648            91.824         16.560
# 546        64.480            20.448            92.448         10.448
#
#      blood_oxygen  eye_movement  sleeping_rate  heart_rate
# 158        82.480        100.40          0.000       75.80
# ...

# %%
import numpy as np
test = [96.320, 26.320, 85.400, 7.160, 82.480, 100.40, 0.000, 75.80]
test = np.array(test).reshape(1,-1)

# %%
xgb.predict(test).tolist()[0]
# Out:
# 3
